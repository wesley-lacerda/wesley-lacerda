# %% [markdown]
# # A) **Início da Jornada**

# %% [markdown]
# ## 0. Início da Jornada

# %% [markdown]
# ### 0.1. **Muito prazer, somos a EBAC!**
#
# Você está iniciando o seu curso Profissão: Cientista de Dados.
# Aqui encontrá videoaulas, fluxogramas, glossários, indicações de materiais extras, atividades práticas e questionários para tornar seu aprendizado eficaz e interativo. Para começar, assista ao vídeo abaixo e veja como é o ecossistema EBAC do qual você faz parte.
#
#
# Boas-vindas!

# %% [markdown]
# ###0.2. **Agora que você já conhece todo o ecossistema da EBAC, queremos conhecer você!**
#
# Responda às questões a seguir para que possamos entender seus anseios, disponibilidades, experiências, o momento que está na sua vida profissional e saber alguns dados demográficos importantes para melhorar nossas formações.

# %% [markdown]
# ###0.3. **Conheça a especialista**

# %% [markdown]
# ###0.4. **Conheça o curso**
#
# **Descubra seu potencial!**
#
# Esta é a sua jornada de aprendizagem, onde você acompanhará as competências e habilidades que desenvolverá ao longo do curso.
#
# Vamos lá?

# %% [markdown]
# ###0.5. **Materiais adicionais**
#
# **Descubra seu potencial!**
#
# Esta é a sua jornada de aprendizagem, onde você acompanhará as competências e habilidades que desenvolverá ao longo do curso.
#
# Vamos lá?

# %% [markdown]
# ###0.6. **Guia do estudante**
#
# **Conheça sua plataforma**
#
# Aqui você verá como avançar no seu curso, enviar trabalhos, comunicar-se com seu tutor e colegas. Todas as informações para que seu aprendizado flua!

# %% [markdown]
# ###0.7. **Junte-se à nossa comunidade!**
#
# **O intuito da nossa comunidade...**
#
# é proporcionar uma experiência de conexão, pertencimento e crescimento coletivo. Aqui, suas vulnerabilidades se transformarão em forças e suas dúvidas conduzirão a descobertas incríveis.
#
# Você encontrará um ambiente de empatia e colaboração, mas também será desafiado, celebrado e inspirado por todos que compartilham do nosso propósito que é capacitar os nossos alunos com habilidades, conhecimentos e ferramentas necessárias para conquistar uma vaga e progredir em suas carreiras.
#
# Em meio a debates, interações e aprendizados, vamos construir memórias e relacionamentos significativos, vamos moldar o futuro juntos, impulsionados pela conexão humana e pelo poder da coletividade.
#
#
#
# **Para que serve a comunidade?**
#
# ***Conecte-se com os colegas***
#
# Participe de conversas com outros estudantes, promovendo um ambiente colaborativo onde ideias fluem e amizades são formadas.
#
# ***Suporte entre pares***
#
# Beneficie-se de uma comunidade solidária onde os alunos compartilham insights, estratégias e experiências, criando uma rede valiosa de colegas que compreendem os desafios e triunfos do aprendizado de dados e programação.
#
# ***Assistência de especialistas***
#
# Procure ajuda diretamente de nossos agentes experientes, prontos para fornecer orientação e suporte, garantindo que você tenha os recursos necessários para se destacar em seus estudos.
#
# ***O que te espera em nossa comunidade?***
#
# Canais de suporte: Acesse canais dedicados para suporte, networking e até assistência na busca de emprego. Se você estiver enfrentando um problema de codificação difícil ou procurando conselhos de carreira, nossa comunidade está aqui para ajudar.
# Eventos e materiais exclusivos: Desfrute de acesso privilegiado a eventos especiais e materiais criados exclusivamente para nossos alunos. Desde webinars com especialistas da indústria até materiais de aprendizado selecionados, projetamos essas ofertas para complementar e aprimorar sua jornada educacional.
# Ao ingressar em nossa Comunidade de Dados e Programação, você abre as portas para um mundo de aprendizado colaborativo, experiências compartilhadas e oportunidades exclusivas adaptadas aos seus objetivos acadêmicos.
#
# **Junte-se à comunidade no Slack:** http://tiny.cc/gkrhvz
#
# Agradecemos por ser uma parte vital de nossa comunidade educacional. Esperamos vê-lo na Comunidade de Dados e Programação!
#
# Atenciosamente,
#
# Equipe EBAC

# %% [markdown]
# ###0.8. **Projeto de Parceria | Semantix!**
#
# ***Construa novas oportunidades***
#
# Neste curso, você tem mais uma oportunidade de aprendizagem: participar do projeto de parceria! A EBAC tem feito parcerias com empresas consolidadas no mercado a fim de garantir que seus estudantes vivenciem experiências práticas por meio da criação de um novo projeto para o seu futuro portfólio e assim desmistificar a complexidade das atividades cotidianas do profissional da área. Os trabalhos mais surpreendentes serão verificados pela empresa e receberão o feedback profissional da Semantix. Os estudantes que se destacarem poderão participar do processo seletivo da empresa parceira.
#
# Trata-se de uma atividade obrigatória caso você esteja no Programa de Empregabilidade e que fará total diferença para o seu desempenho profissional! Que tal conhecer com mais detalhes nosso projeto de parceria?

# %% [markdown]
# ###0.9. **Eventos ao vivo**
#
# ***Explore e evolua em tempo real***
#
# Na programação exclusiva da EBAC, você explora uma variedade de experiências dinâmicas e enriquecedoras. De workshops interativos a palestras inspiradoras, nossos eventos online oferecem conteúdos relevantes, proporcionando grandes oportunidades de aprendizado. Nossa plataforma é acessível e envolvente e visa expandir seus horizontes acadêmicos e profissionais. Junte-se a nós enquanto exploramos novas formas de aprendizado e colaboração no mundo digital!
#
# ***Na nossa programação ao vivo exclusiva, você…***
#
# Participa de aulas interativas ao vivo com conteúdo atualizado e alinhado com o mercado de trabalho, proporcionando oportunidades de desenvolvimento profissional em diversas áreas
# Tira dúvidas em tempo real com nossos professores, tutores e convidados
# Faz networking e cria conexões com outros colegas
# Recebe suporte e dicas valiosas para seguir estudando e concluir o seu curso
# Desenvolve habilidades importantes para o seu sucesso profissional
# Apresenta seus projetos e recebe feedbacks de especialistas ao vivo.
#
#
# **Confira a agenda "Ao Vivo" na plataforma.**

# %% [markdown]
# # B) **Fundamentos de Ciência de Dados e Machine Learning**

# %% [markdown]
# ## 1. Introdução a Ciência de Dados

# %% [markdown]
# ###1.0 **Sobre o trajeto**
#
# ***Módulo 1***
#
# Olá, desejamos boas-vindas ao módulo Introdução a Ciência de Dados do curso Profissão: Cientista de Dados.
# Neste módulo, você será introduzido ao fascinante mundo da Ciência de Dados, explorando sua importância crescente na sociedade moderna e suas aplicações em diversos setores. Vamos abordar conceitos fundamentais e o papel dos profissionais da área:
#
# ***Conceito de Dados e Big Data***
#
# Entenda o que são dados e como eles se transformam em conhecimento. Explore o conceito de Big Data e a necessidade de novas abordagens para lidar com o volume e a complexidade dos dados na era digital.
#
# ***Funções na Ciência de Dados***
#
# Descubra as diferentes funções dentro do campo de dados, como engenheiros, cientistas e analistas de dados, e como essas funções se complementam para extrair valor dos dados em diferentes contextos empresariais.
#
# ***Aplicações e Projetos em Ciência de Dados***
#
# Explore as aplicações práticas da ciência de dados em setores como saúde, comércio e inteligência artificial. Aprenda sobre a importância de monitorar modelos de machine learning e a análise de churn para negócios.
#
# Este módulo é o primeiro passo na sua jornada para se tornar um cientista de dados. Enfrente os desafios com determinação e curiosidade, e prepare-se para aplicar os conceitos aprendidos em atividades práticas. Estamos ansiosos para ver você progredir e alcançar seus objetivos profissionais. Continue avançando e prepare-se para o próximo módulo!

# %% [markdown]
# ###1.1 **O que são Dados?**
#
# ***Estamos iniciando a nossa aula. Nesse momento, dê play para:***
#
# - Definir o conceito de dados e sua importância no mundo moderno;
# - Descrever a ubiquidade dos dados em diversas áreas do cotidiano;
# - Analisar o impacto do Big Data no processamento de informações.

# %% [markdown]
# ###1.2 **Conheça a área de Dados**
#
# - Estamos iniciando a nossa aula. Nesse momento, dê play para:
# - Definir as funções de engenheiro, cientista e analista de dados;
# - Descrever a importância do Big Data na área de dados;
# Analisar a inter-relação entre diferentes funções na área de dados.

# %% [markdown]
# ###1.3 **Torne-se um profissional de Dados**
#
# ***Estamos iniciando a nossa aula. Nesse momento, dê play para:***
#
# - Identificar aplicações da ciência de dados em diversos setores;
# - Examinar o papel do cientista de dados em manipulação e análise de dados;
# - Propor soluções baseadas em modelos de inteligência artificial.

# %% [markdown]
# ###1.4 **Aprenda como e onde aplicar Ciência de Dados**
#
# ***Estamos iniciando a nossa aula. Nesse momento, dê play para:***
#
# - Definir aplicações práticas da ciência de dados em diversos contextos;
# - Explicar o uso de machine learning para prever comportamentos e detectar fraudes;
# - Analisar etapas de um projeto de ciência de dados para garantir seu sucesso.

# %% [markdown]
# ###1.5 **Glossário**
#
# ***Módulo 1***
#
# ***Lembre-se dos termos mais utilizados durante o módulo.***
#
# **Análise de Churn**
#
# Processo de identificar e analisar os motivos pelos quais clientes deixam de usar um serviço ou produto, ajudando empresas a desenvolver estratégias para retenção de clientes.
#
# **Big Data**
#
# Conjunto de dados de grande volume, variedade e velocidade que requerem novas formas de processamento para permitir insights e tomada de decisão.
#
# **Ciência de Dados**
#
# Disciplina que combina estatística, computação e conhecimento de negócios para extrair insights de dados e apoiar a tomada de decisões.
#
# **Detecção de Anomalias**
#
# Identificação de padrões que não seguem o comportamento esperado em um conjunto de dados, frequentemente usada para detectar fraudes ou erros.
#
# **Engenheiro de Dados**
#
# Profissional responsável por construir e manter a infraestrutura necessária para a coleta, armazenamento e processamento de grandes volumes de dados.
#
# **Inteligência Artificial**
#
# Campo da ciência da computação que desenvolve sistemas capazes de realizar tarefas que normalmente requerem inteligência humana, como reconhecimento de fala e tomada de decisão.
#
# **Modelos de Machine Learning**
#
# Algoritmos que aprendem padrões a partir de dados para fazer previsões ou tomar decisões sem serem explicitamente programados para realizar a tarefa.
#
# **Monitoramento de Modelos**
#
# Processo de acompanhar o desempenho de modelos de machine learning em produção para garantir que continuem a fornecer resultados precisos e relevantes.
#
# **Previsão de Surtos**
#
# Uso de dados e modelos analíticos para antecipar a ocorrência de eventos, como surtos de doenças, permitindo uma melhor alocação de recursos e planejamento.
#
# **Sistemas de Assistência ao Motorista**
#
# Tecnologias que utilizam dados e inteligência artificial para auxiliar motoristas em tarefas como estacionamento, manutenção de faixa e prevenção de colisões.

# %% [markdown]
# ###1.6 **Boas práticas**
#
# *Módulo 1*
#
# ***Nesta seção você encontrará informações importantes que te ajudarão a aplicar efetivamente o que aprendeu***
#
# **Entendimento do Conceito de Dados**
#
# Compreender que dados são mais do que números e textos; eles são informações que, quando processadas, se transformam em conhecimento. Isso é fundamental para qualquer cientista de dados, pois a interpretação correta dos dados é a base para insights valiosos.
#
# **Familiarização com Big Data**
#
# Reconhecer a importância do Big Data e as novas abordagens necessárias para lidar com grandes volumes de dados. Isso inclui entender as limitações dos métodos tradicionais e a necessidade de ferramentas especializadas.
#
# **Interdisciplinaridade na Ciência de Dados**
#
# A ciência de dados é uma área interdisciplinar que combina computação, estatística e negócios. Desenvolver habilidades em todas essas áreas é crucial para construir modelos eficazes e tomar decisões informadas.
#
# **Aplicação Prática dos Conceitos**
#
# Aplicar os conceitos aprendidos em atividades práticas, como identificar exemplos de dados gerados no dia a dia e relacionar esses conceitos com Big Data e Ciência de Dados. Isso ajuda a solidificar o entendimento e prepara para aplicações no mundo real.
#
# ***Exemplo de utilização no mercado de trabalho:***
#
# - **Previsão de Surtos de Doenças:** Na área da saúde, a ciência de dados é utilizada para prever surtos de doenças, permitindo que recursos médicos sejam alocados de forma mais eficiente e que medidas preventivas sejam implementadas a tempo.
#
# - **Análise de Comportamento de Clientes:** No comércio, a análise de dados ajuda a entender padrões de compra e preferências dos clientes, permitindo que as empresas personalizem suas ofertas e melhorem a satisfação do cliente.

# %% [markdown]
# ###1.7 **Reforce seu conhecimento**
#
# *Módulo 1*
#
# **Antes de revisar as respostas, tente respondê-las você mesmo; Isso te ajudará a fortalecer sua compreensão. Esta é uma ótima maneira de aprender!**
#
# **O que são dados e por que são importantes na sociedade contemporânea?**
#
# Dados são fatos ou informações que, quando processados, se transformam em conhecimento. Eles são importantes na sociedade contemporânea porque influenciam decisões em diversas áreas, como saúde, educação, marketing e transporte, especialmente após a pandemia da Covid-19, que destacou ainda mais sua relevância.
#
# **O que é Big Data e por que é necessário?**
#
# Big Data refere-se ao grande volume e complexidade dos dados que não podem ser processados por métodos tradicionais. É necessário porque o aumento exponencial de dados exige novas abordagens e ferramentas para gerenciá-los e extrair informações valiosas.
#
# **Quais são as principais funções na área de dados?**
#
# As principais funções na área de dados incluem engenheiros de dados, que constroem e mantêm a infraestrutura para a gestão de grandes volumes de dados; cientistas de dados, que combinam conhecimentos de computação, estatística e negócios para construir modelos de decisão; e analistas de dados, que elaboram dashboards e análises para compreender decisões de negócios.
#
# **Como a ciência de dados é aplicada em diferentes setores?**
#
# A ciência de dados é aplicada em diversos setores, como saúde, para prever surtos de doenças e otimizar recursos médicos; comércio, para entender padrões de compra e preferências dos clientes; e na construção de modelos de inteligência artificial, como sistemas de assistência ao motorista e chatbots.
#
# **Qual é a importância de monitorar modelos de machine learning?**
#
# Monitorar modelos de machine learning é importante para garantir que eles continuem eficazes mesmo quando padrões mudam. Isso assegura que as soluções funcionem conforme esperado e permite ajustes quando necessário.
#
# **O que é análise de churn e por que é crucial para negócios?**
#
# A análise de churn é o processo de identificar clientes que estão propensos a deixar um serviço ou produto. É crucial para negócios porque ajuda a identificar problemas de satisfação e concorrência, permitindo que as empresas tomem medidas para reter clientes.
#
# **Como os alunos são incentivados a aplicar os conceitos aprendidos?**
#
# Os alunos são incentivados a aplicar os conceitos aprendidos em uma atividade prática, onde devem explicar o que são dados, identificar exemplos de dados gerados ao longo do dia, e relacionar os conceitos de Big Data e Ciência de Dados. Isso ajuda a consolidar o aprendizado e explorar como aplicar esses conhecimentos em seus objetivos pessoais ou profissionais.
#
# **Por que é importante o planejamento e execução cuidadosa de projetos de ciência de dados?**
#
# O planejamento e execução cuidadosa de projetos de ciência de dados são importantes para garantir que as soluções funcionem conforme esperado, permitindo ajustes quando necessário. Isso assegura que os projetos alcancem seus objetivos e gerem valor para as organizações.
#
# **Como a pandemia da Covid-19 destacou a importância dos dados?**
#
# A pandemia da Covid-19 destacou a importância dos dados ao mostrar como eles podem ser usados para monitorar a propagação do vírus, alocar recursos médicos de forma eficiente e informar políticas públicas. Isso reforçou a necessidade de habilidades em ciência de dados para lidar com desafios complexos.
#
# **Quais são as motivações dos alunos para escolher o curso de Ciência de Dados?**
#
# As motivações dos alunos para escolher o curso de Ciência de Dados podem incluir o desejo de adquirir habilidades valiosas para o mercado de trabalho, interesse em resolver problemas complexos usando dados e a intenção de aplicar esses conhecimentos em seus objetivos pessoais ou profissionais.

# %% [markdown]
# ###1.8 **Quiz**
#
# Pergunta 1
#
# O que são dados? **negrito**
#
# Representações simbólicas de informações.
# correto
# Nível de dificuldade: fácil.
#
# Caso tenha dificuldade com essa questão, revisite Aula 1.
#
# Feedback:
#
# a) Programas de computador - Esta opção está incorreta. Dados não são programas de computador. Dados referem-se a informações brutas que podem ser processadas e interpretadas.
#
# c) Redes de comunicação - Esta opção está incorreta. Redes de comunicação envolvem a transmissão de dados, mas dados em si não são redes de comunicação.
#
# d) Estruturas de armazenamento - Esta opção está incorreta. Estruturas de armazenamento são locais onde os dados podem ser armazenados, mas os dados em si são a representação das informações.
#
# Portanto, a alternativa correta é b) Representações simbólicas de informações, pois dados são informações em uma forma simbólica que pode ser processada por computadores ou compreendida por seres humanos.
#
# **Pergunta 2**
#
# Avalie cada afirmação abaixo e indique o que é Verdadeiro e o que é Falso:
#
# I. O Big Data refere-se apenas à quantidade de dados.
#
# II. Empresas não precisam lidar com Big Data, pois seus dados são sempre pequenos.
#
# III. Big Data é crucial para análise de dados em tempo real.
#
# IV. O termo Big Data se concentra apenas na estrutura dos dados.
#
# V. Big Data é uma preocupação exclusiva de empresas de tecnologia.
#
# I. Falso | II. Falso | III. Verdadeiro | IV. Falso | V. Falso
# correto
# Nível de dificuldade: intermediário.
#
# Caso tenha dificuldade com essa questão, revisite a Aula 1.
#
# Feedback:
#
# I. Falso - Big Data envolve volume, velocidade e variedade.
#
# II. Falso - Empresas de todos os setores podem lidar com grandes volumes de dados.
#
# III. Verdadeiro - Big Data é útil para análise em tempo real.
#
# IV. Falso - Big Data também envolve a velocidade e variedade dos dados.
#
# V. Falso - Empresas de diversos setores podem se beneficiar do Big Data.
#
# Pergunta 3
#
# Analise as afirmações a seguir e assinale a alternativa correta:
# **negrito**
# I. O Cientista de Dados se concentra principalmente na infraestrutura de dados.
# II. Projetos de Dados envolvem apenas análise retrospectiva.
# III. A aplicação da Ciência de Dados pode ser benéfica em vários setores, não apenas em tecnologia.
# IV. As etapas de um projeto de Dados incluem apenas a coleta e análise de dados.
# Apenas III é verdadeira.
# correto
# Nível de dificuldade: difícil.
#
# Caso tenha dificuldade com essa questão, revisite a Aula 2.
#
# Feedback:
#
# I. O Cientista de Dados se concentra principalmente na infraestrutura de dados - Esta afirmação é falsa. A infraestrutura de dados é mais central para o papel do Engenheiro de Dados.
#
# II. Projetos de Dados envolvem apenas análise retrospectiva - Esta afirmação é falsa. Projetos de Dados podem envolver análise retrospectiva, mas também incorporam análise preditiva e prescritiva. A Ciência de Dados não se limita à análise retrospectiva, pois busca prever futuros eventos e fornecer recomendações para ações.
#
# III. A aplicação da Ciência de Dados pode ser benéfica em vários setores, não apenas em tecnologia - Esta afirmação é verdadeira. A Ciência de Dados tem aplicações em diversos setores, como saúde, finanças, varejo e manufatura. A capacidade de analisar dados e obter insights pode ser valiosa em contextos empresariais diversos.
#
# IV. As etapas de um projeto de Dados incluem apenas a coleta e análise de dados - Esta afirmação é falsa. As etapas de um projeto de Dados abrangem diversas fases, incluindo a definição do problema, a coleta de dados, a limpeza e preparação dos dados, a modelagem, a interpretação dos resultados e a implementação de soluções baseadas nos insights obtidos.
#
# Pergunta 4
#
# Qual é a importância da aplicação da Ciência de Dados em projetos empresariais? ***texto em itálico***
#
# A Ciência de Dados ajuda a identificar oportunidades de mercado, prever tendências e otimizar processos. **negrito**
# correto
# Nível de dificuldade: difícil.
#
# Caso tenha dificuldade com essa questão, revisite a Aula 4.
#
# Feedback:
#
# a) A Ciência de Dados é relevante apenas para empresas de tecnologia - Esta opção está incorreta. A Ciência de Dados tem aplicação em uma variedade de setores, não se limitando apenas a empresas de tecnologia. Empresas de saúde, finanças, varejo, entre outras, também se beneficiam da análise de dados.
#
# c) A Ciência de Dados é exclusiva para análise de dados retrospectiva - Esta opção está incorreta. Embora a análise retrospectiva seja uma parte da Ciência de Dados, ela também envolve análise preditiva e prescritiva, buscando insights para o futuro e recomendações para ação.
#
# d) A Ciência de Dados não tem impacto significativo nos resultados financeiros das empresas - A Ciência de Dados pode ter um impacto significativo nos resultados financeiros das empresas, ajudando na tomada de decisões informadas, identificação de eficiências operacionais e maximização de oportunidades de mercado.
#
# Portanto, a alternativa correta é b) A Ciência de Dados ajuda a identificar oportunidades de mercado, prever tendências e otimizar processos, pois reflete a ampla gama de aplicações e benefícios que a Ciência de Dados proporciona às empresas.

# %% [markdown]
# ###1.9 **Pratique**
#
# **Que tal praticar?**
#
# ***Passo a passo***
#
# 1. Explique com suas palavras o que são dados.
#
# 2. Identifique pelo menos 3 exemplos possíveis de dados que você gerou hoje durante o dia.
#
# 3. Relacione com suas palavras Big Data e Ciência de Dados.
#
# Também queremos te conhecer! Conte o que te levou ao curso de Ciência de Dados.
#
# Já pensou em como irá aplicar Ciência de Dados para alcançar seus objetivos? Se sim, como?
#
# Tempo estimado para resolução: 20 minutos
#
# Como submeter sua entrega: Envie em formato PDF, que deverá ser criado a partir do software de sua preferência: Word ou PowerPoint.

# %% [markdown]
# ###1.10 **Recapitule a jornada**
#
# *Módulo 1*
#
# **Parabéns por ter finalizado este módulo! Confira a competência e as habilidades que você adquiriu:**
#
# ***Competência:***
#
# Compreender a importância dos dados na sociedade atual e aplicar conceitos de Big Data e Ciência de Dados em diversos contextos.
#
# **Habilidades:**
# - 1
# Definir o que são dados e identificar exemplos de dados gerados no cotidiano.
#
# - 2
# Descrever o conceito de Big Data e explicar sua importância na análise de grandes volumes de dados.
#
# - 3
# Aplicar conceitos de Ciência de Dados em projetos práticos, como previsão de tendências e detecção de fraudes.
#
# - 4
# Analisar o papel de cientistas, engenheiros e analistas de dados em diferentes setores e suas funções específicas.

# %% [markdown]
# ## 2. Machine Learning 1: Conceitos Primários

# %% [markdown]
# ### **2.0 Sobre o trajeto**

# %% [markdown]
# **Módulo 2**
#
# ***Olá, desejamos boas-vindas ao módulo Machine Learning 1: Conceitos Primários do curso Profissão: Cientista de Dados.***
#
# Este módulo oferece uma introdução abrangente aos conceitos fundamentais de machine learning e estatística, destacando sua aplicação prática na ciência de dados. Você aprenderá sobre a lógica do machine learning, a importância dos dados e a integração entre programação e estatística:
#
# ***Lógica do Machine Learning***
#
# Entenda como os computadores são treinados para aprender padrões e realizar tarefas com base em dados, sem a necessidade de comandos explícitos. Explore o processo de machine learning, que inclui fornecimento de dados, identificação de padrões e avaliação do desempenho do modelo.
#
# ***Integração de Programação e Estatística***
#
# Descubra como a estatística é um dos pilares fundamentais para o funcionamento dos modelos de aprendizado de máquina e como a programação, especialmente em Python e SQL, é essencial para processar grandes volumes de dados de forma eficiente.
#
# ***Modelos Preditivos e Descritivos***
#
# Aprenda sobre os principais tipos de modelos utilizados na ciência de dados: preditivos, para prever eventos futuros, e descritivos, para entender padrões existentes nos dados. Explore algoritmos de aprendizado supervisionado e não supervisionado.
#
# Este módulo é um passo importante na sua jornada para se tornar um cientista de dados. Ao final, você terá uma compreensão sólida dos fundamentos de machine learning e estatística, pronto para aplicar esse conhecimento em projetos práticos. Estamos ansiosos para ver seu progresso!

# %% [markdown]
# ### **2.1 Descubra o Machine Learning**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir os conceitos básicos de machine learning e sua aplicação prática;
# - Descrever o processo de aprendizado de máquina em etapas claras e lógicas;
# - Analisar a importância da qualidade dos dados no desempenho do modelo.

# %% [markdown]
# ### **2.2 Combine Programação e Estatística para Machine Learning**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Discutir a integração entre programação e estatística em ciência de dados;
# - Aplicar conceitos estatísticos para melhorar modelos de aprendizado de máquina;
# - Analisar gráficos estatísticos para identificar outliers nos dados.

# %% [markdown]
# ### **2.3 Utilize Métodos Preditivos e Descritivos**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir os conceitos de modelos preditivos e descritivos em ciência de dados;
# - Explicar a lógica e aplicações dos modelos preditivos e descritivos;
# - Aplicar modelos preditivos e descritivos utilizando Python.

# %% [markdown]
# ### **2.4 Implemente a Metodologia Crisp-DM**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir os objetivos do negócio para projetos de ciência de dados;
# - Examinar as etapas do CRISP-DM para mineração de dados eficaz;
# - Aplicar a metodologia CRISP-DM em projetos de ciência de dados.

# %% [markdown]
# ### **2.5 Glossário**

# %% [markdown]
# ***Módulo 2***
#
# ***Lembre-se dos termos mais utilizados durante o módulo.
# CRISP-DM***
#
# Metodologia padrão para a condução de projetos de ciência de dados, composta por etapas como compreensão dos objetivos do negócio, preparação dos dados, modelagem e avaliação do modelo, garantindo uma abordagem organizada e eficiente.
#
# **Modelos Descritivos**
#
# Modelos utilizados para entender e descrever padrões existentes nos dados, frequentemente aplicando algoritmos de aprendizado não supervisionado, como agrupamento e redução de dimensionalidade.
#
# **Modelos Preditivos**
#
# Modelos que incluem técnicas de classificação e regressão, usados para prever eventos futuros ou estimar valores desconhecidos com base em dados históricos.
#
# **Redução de Dimensionalidade**
#
# Técnica de aprendizado não supervisionado utilizada para reduzir o número de variáveis em um conjunto de dados, mantendo a maior quantidade possível de informação relevante.

# %% [markdown]
# ### **2.6 Boas práticas**

# %% [markdown]
# ***Módulo 2***
#
# ***Nesta seção você encontrará informações importantes que te ajudarão a aplicar efetivamente o que aprendeu.***
#
# **Compreensão dos Dados**
#
# Antes de aplicar qualquer modelo de machine learning, é crucial entender a natureza dos dados. Isso inclui a identificação de variáveis relevantes, análise de distribuições e detecção de valores ausentes ou anômalos. Uma compreensão sólida dos dados garante que o modelo seja treinado de forma eficaz.
#
# **Qualidade dos Dados**
#
# A qualidade dos dados é fundamental para o sucesso de qualquer projeto de machine learning. Dados de baixa qualidade podem levar a modelos imprecisos. Portanto, é importante realizar limpeza e pré-processamento dos dados, garantindo que estejam prontos para análise.
#
# **Integração de Programação e Estatística**
#
# A programação, especialmente em Python, é uma ferramenta essencial para manipular e analisar grandes volumes de dados. A integração com conceitos estatísticos permite a criação de modelos mais robustos e a realização de análises mais precisas.
#
# **Aplicação da Metodologia CRISP-DM**
#
# Seguir a metodologia CRISP-DM ajuda a estruturar projetos de ciência de dados de maneira organizada. As etapas incluem compreensão do negócio, preparação dos dados, modelagem e avaliação, garantindo que o projeto atenda aos objetivos definidos.
#
# **Exemplo de utilização no mercado de trabalho:**
#
# - **Previsão de Vendas:** Empresas utilizam modelos preditivos para estimar vendas futuras com base em dados históricos, ajustando estratégias de marketing e estoque de acordo com as previsões.
#
# - **Análise de Comportamento do Cliente:** Modelos descritivos são usados para identificar padrões de comportamento dos clientes, permitindo que as empresas personalizem ofertas e melhorem a experiência do clientes.

# %% [markdown]
# ### **2.7 Reforce seu conhecimento**

# %% [markdown]
# ***Módulo 2***
#
# ***Antes de revisar as respostas, tente respondê-las você mesmo, isso te ajudará a fortalecer sua compreensão. Esta é uma ótima maneira de aprender!***
#
# **O que é machine learning e como ele funciona?**
#
# Machine learning é uma área da ciência da computação que permite que os computadores aprendam padrões e realizem tarefas com base em dados, sem a necessidade de comandos explícitos. O processo de machine learning é dividido em três etapas principais: fornecimento de dados, identificação de padrões pelo algoritmo e avaliação do desempenho do modelo.
#
# **Por que a qualidade e quantidade dos dados são importantes em machine learning?**
#
# A qualidade e quantidade dos dados são cruciais porque dados de baixa qualidade podem prejudicar o desempenho do modelo. Dados precisos e abrangentes permitem que o modelo aprenda padrões de forma eficaz, resultando em previsões mais precisas e confiáveis.
#
# **Qual é o papel da estatística na ciência de dados?**
#
# A estatística é um dos pilares fundamentais da ciência de dados, essencial para o funcionamento dos modelos de aprendizado de máquina. Conceitos estatísticos são utilizados para melhorar o desempenho dos modelos e são amplamente aplicados na análise de dados, incluindo cálculos de média, mediana e desvio padrão, além de validações e testes de hipóteses.
#
# **Como a programação é utilizada na ciência de dados?**
#
# A programação é uma ferramenta essencial para processar grandes volumes de dados de forma eficiente. Linguagens como Python e SQL são destacadas por sua capacidade de manipular dados, construir modelos de machine learning e realizar análises estatísticas.
#
# **Quais são os principais tipos de modelos utilizados na ciência de dados?**
#
# Os principais tipos de modelos na ciência de dados são preditivos e descritivos. Modelos preditivos, como classificação e regressão, são usados para prever eventos futuros ou estimar valores desconhecidos. Modelos descritivos são usados para entender e descrever padrões existentes nos dados, utilizando algoritmos de aprendizado não supervisionado, como agrupamento e redução de dimensionalidade.
#
# **O que é a metodologia CRISP-DM e por que é importante?**
#
# A metodologia CRISP-DM é uma estrutura essencial para a condução de projetos de ciência de dados. Ela garante que os projetos sejam realizados de maneira organizada e eficiente, seguindo etapas como compreensão dos objetivos do negócio, preparação dos dados, modelagem e avaliação do modelo. Seguir essas etapas na ordem correta ajuda a evitar problemas e retrabalho.
#
# **Qual é a importância de entender a lógica do machine learning antes de se aprofundar nos conceitos matemáticos e de programação?**
#
# Compreender a lógica do machine learning é essencial porque fornece uma base sólida para entender como os modelos funcionam e como eles podem ser aplicados a problemas do mundo real. Isso facilita o aprendizado dos conceitos matemáticos e de programação subjacentes, permitindo que os alunos desenvolvam modelos mais eficazes.

# %% [markdown]
# ### **2.8 Quiz**

# %% [markdown]
# Pergunta 1
# Qual é o principal objetivo dos modelos preditivos em machine learning?
# Estimar valores desconhecidos com base em informações conhecidas.
# correto
# Nível de dificuldade: fácil.
#
# Caso tenha dificuldade com essa questão, revisite a Aula 3.
#
# Feedback:
#
# A alternativa correta é "Estimar valores desconhecidos com base em informações conhecidas".
#
# Os modelos preditivos em machine learning são utilizados para estimar valores desconhecidos com base em informações conhecidas, permitindo fazer previsões ou estimativas sobre eventos futuros. As demais alternativas estão incorretas porque descrever padrões existentes, identificar grupos semelhantes e analisar grandes conjuntos de dados são mais associados a outros métodos ou objetivos da ciência de dados.
#
# Pergunta 2
# Avalie cada afirmação abaixo e indique o que é Verdadeiro e o que é Falso:
# I. A etapa de Modelagem no CRISP-DM é onde os dados são preparados para análise.
#
# II. Na etapa de Preparação de Dados do CRISP-DM, busca-se entender os objetivos do projeto.
#
# III. O CRISP-DM é uma metodologia popular na área de segurança de redes.
#
# IV. Na Avaliação do CRISP-DM, é importante validar se o modelo atende aos objetivos do negócio.
#
# V. Seguir as etapas do CRISP-DM na ordem correta pode evitar retrabalhos no projeto.
#
# I. Falso | II. Verdadeiro | III. Falso | IV. Verdadeiro | V. Verdadeiro
# correto
# Nível de dificuldade: Intermediário.
#
# Caso tenha dificuldade com essa questão, a Aula 4.
#
# Feedback:
#
# I.. Falso. Na etapa de Modelagem no CRISP-DM, os modelos são escolhidos e construídos.
#
# II. Verdadeiro. Na etapa de Preparação de Dados do CRISP-DM, é crucial entender os objetivos do projeto.
#
# III. Falso. O CRISP-DM é uma metodologia popular na área de ciência de dados, não especificamente em segurança de redes.
#
# IV. Verdadeiro. Na Avaliação do CRISP-DM, é fundamental validar se o modelo atende aos objetivos do negócio.
#
# V. Verdadeiro. Seguir as etapas do CRISP-DM na ordem correta pode evitar retrabalhos no projeto.
#
# Pergunta 3
# Associe os métodos descritivos aos seus respectivos propósitos:
# a) Associação por similaridade
# b) Agrupamento
# c) Redução de dimensionalidade
#
# 1. Identificar grupos de dados semelhantes.
# 2. Simplificar um conjunto de dados complexo.
# 3. Identificar itens que são comprados juntos.
#
#
# a-3, b-1, c-2
# correto
# Nível de dificuldade: Intermediário.
#
# Caso tenha dificuldade com essa questão, revisite a Aula 3.
#
# Feedback:
#
# Nesta questão, associamos os métodos descritivos aos seus respectivos propósitos. A associação correta é:
#
# Associação por similaridade (a) - Identificar itens que são comprados juntos (III)
#
# Agrupamento (b) - Identificar grupos de dados semelhantes (I)
#
# Redução de dimensionalidade (c) - Simplificar um conjunto de dados complexo (II)
#
# As demais alternativas estão incorretas:
#
# A alternativa "a-1, b-2, c-3" associa corretamente a Associação por similaridade ao propósito de Identificar grupos de dados semelhantes, mas as outras associações estão trocadas.
#
# A alternativa "a-2, b-3, c-1" troca todas as associações, não correspondendo aos propósitos corretos de cada método descritivo.
#
# Pergunta 4
# Analise as seguintes afirmações e escolha a opção correta:
# I. O CRISP-DM é baseado no método científico e representa um processo padrão de mineração de dados.
# II. A etapa de Modelagem no CRISP-DM é onde os dados são explorados e preparados para análise.
# III. O método descritivo mais usado no mercado é a regressão.
# IV. A classificação é usada para prever categorias nos dados.
# Apenas I e IV estão corretas.
# correto
# Nível de dificuldade: difícil.
#
# Caso tenha dificuldade com essa questão, revisite a Aula 4.
#
# Feedback:
#
# I. O CRISP-DM é baseado no método científico e representa um processo padrão de mineração de dados.
#
# Esta afirmação está correta. O CRISP-DM é de fato baseado no método científico e é amplamente reconhecido como um processo padrão para mineração de dados.
#
# II. A etapa de Modelagem no CRISP-DM é onde os dados são explorados e preparados para análise.
#
# Esta afirmação está incorreta. Na verdade, a etapa de Modelagem no CRISP-DM é onde os dados são explorados, preparados e modelados para análise.
#
# III. O método descritivo mais usado no mercado é a regressão logística.
#
# Esta afirmação está incorreta. Na verdade, a regressão logística é um método preditivo, não descritivo. Além disso, outros métodos descritivos, como a clusterização, também são amplamente utilizados.
#
# IV. A classificação é usada para prever categorias nos dados.
#
# Esta afirmação está correta. A classificação é usada para prever valores numéricos ou categorias nos dados, dependendo do tipo de regressão utilizada.

# %% [markdown]
# ### **2.9 Pratique**

# %% [markdown]
# **Que tal praticar?**
#
# **Passo a passo:**
#
# 1. Explique com suas palavras o conceito de Machine Learning.
#
# 2. Diferencie modelos descritivos de modelos preditivos.
#
# 3. Pesquise aplicações de modelos de machine learning voltados para sua área de interesse e descreva exemplificando o que encontrou.
#
# 4. Escolha um das aplicações que citou acima e descreva como você imaginaria que seriam aplicadas as etapas do Crisp-DM a esse projeto.
#
# *Relembre as etapas: entendimento do negócio, entendimento dos dados, preparação dos dados, modelagem e avaliação dos modelos.*
#
# Tempo estimado para resolução: 40 minutos

# %% [markdown]
# ### **2.10 Recapitule a jornada**

# %% [markdown]
# ***Módulo 2***
#
# ***Parabéns por ter finalizado este módulo! Confira a competência e as habilidades que você adquiriu:***
#
# **Competência:**
#
# Integrar conceitos de machine learning e estatística para desenvolver modelos preditivos e descritivos aplicados à ciência de dados.
#
# **Habilidades:**
# 1. Apontar a importância da qualidade dos dados para o desempenho dos modelos de machine learning.
#
# 2. Descrever o processo de machine learning, incluindo fornecimento de dados, identificação de padrões e avaliação de modelos.

# %% [markdown]
# ## 3. Introdução à Programação

# %% [markdown]
# ### 3.0 **Sobre o trajeto**

# %% [markdown]
# **Módulo 3**
#
# **Olá, desejamos boas-vindas ao módulo Introdução à Programação do curso Profissão: Cientista de Dados.**
#
# Neste módulo, você será introduzido ao mundo da programação e análise de dados, com foco especial na lógica de programação. Este é um alicerce essencial para resolver problemas de forma eficiente e compreender algoritmos. Vamos explorar conceitos fundamentais que servirão como base para seu aprendizado em linguagens de programação, como Python:
#
# **Lógica de Programação**
#
# Entenda a importância da lógica de programação como a base para qualquer linguagem. Aprenda a estruturar seu pensamento para resolver problemas de forma eficiente antes de se aprofundar em linguagens específicas.
#
# **Conceitos Fundamentais**
#
# Explore conceitos essenciais como variáveis e estruturas de repetição. Compreenda como esses elementos são utilizados para automatizar tarefas e manipular dados de forma eficaz em qualquer linguagem de programação.
#
# **Ferramentas de Programação**
#
# Familiarize-se com ferramentas como Portugol, Google Colab e Jupyter Notebook. Descubra como essas plataformas podem facilitar seu aprendizado e prática de programação, preparando-o para o uso de linguagens como Python.
#
# Este módulo é o primeiro passo em sua jornada para se tornar um cientista de dados. Ao dominar a lógica de programação e os conceitos fundamentais, você estará bem preparado para enfrentar desafios mais complexos nos próximos módulos. Estamos aqui para apoiá-lo em cada etapa do caminho!

# %% [markdown]
# ### 3.1 **Conheça a Programação**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir o conceito de lógica de programação e sua importância;
# - Descrever as características de diferentes linguagens de programação;
# - Aplicar a lógica de programação em problemas básicos.

# %% [markdown]
# ### 3.2 **Conheça os conceitos básicos - Parte 1**

# %% [markdown]
# Estamos iniciando a nossa aula. Nesse momento, dê play para:
#
# - Definir os conceitos fundamentais de lógica de programação;
# - Descrever a importância da lógica antes de aprender linguagens;
# - Aplicar algoritmos simples em exemplos práticos de jogos.

# %% [markdown]
# ### 3.3 **Conheça os conceitos básicos - Parte 2**

# %% [markdown]
# Estamos iniciando a nossa aula. Nesse momento, dê play para:
#
# - Definir variáveis e suas regras de nomenclatura em programação;
# - Explicar tipos de dados e sua importância em variáveis;
# - Aplicar estruturas de repetição para automatizar tarefas.

# %% [markdown]
# ### 3.4 **Crie algoritimos com Portugol - Parte 1**

# %% [markdown]
# Estamos iniciando a nossa aula. Nesse momento, dê play para:
#
# - Definir a estrutura básica de um programa no Portugol;
# - Descrever o uso de variáveis em operações matemáticas simples;
# - Aplicar a lógica de programação em algoritmos básicos no Portugol.

# %% [markdown]
# ### 3.5 **Crie algoritimos com Portugol - Parte 2**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir variáveis para armazenar dados em algoritmos complexos;
# - Explicar a lógica condicional em algoritmos de decisão;
# - Praticar estruturas de repetição para cálculos eficientes.

# %% [markdown]
# ### 3.6 **Conheça o Google Colab e o Jupyter Notebook**

# %% [markdown]
# Estamos iniciando a nossa aula. Nesse momento, dê play para:
#
# - Identificar as funcionalidades básicas do Google Colab e Jupyter Notebook;
# - Demonstrar como acessar e operar as plataformas de programação em Python;
# - Comparar as vantagens e limitações do Google Colab e Jupyter Notebook.

# %% [markdown]
# ### 3.7 **Glossário**

# %% [markdown]
# **Módulo 3**
#
# **Lembre-se dos termos mais utilizados durante o módulo.**
#
# - **Fluxograma**
#
# Uma representação visual de um processo ou algoritmo, usando símbolos padronizados para descrever as etapas e a sequência de ações necessárias para resolver um problema ou executar uma tarefa.
#
# - **Portugol**
#
# Uma ferramenta educacional que permite a prática de lógica de programação em português, facilitando o aprendizado de conceitos básicos antes de migrar para linguagens de programação mais complexas como Python.

# %% [markdown]
# ### 3.8 **Boas práticas**

# %% [markdown]
# ***Módulo 3***
#
# **Nesta seção você encontrará informações importantes que te ajudarão a aplicar efetivamente o que aprendeu.**
#
# ***Compreensão da Lógica de Programação***
#
# Antes de mergulhar em qualquer linguagem de programação, é crucial entender a lógica de programação. Isso serve como um alicerce para resolver problemas de forma eficiente e compreender algoritmos. A lógica de programação ajuda a estruturar o pensamento e a criar soluções sistemáticas para problemas complexos.
#
# ***Uso de Ferramentas de Ensino***
#
# Ferramentas como fluxogramas e Portugol são excelentes para iniciantes praticarem lógica de programação. Elas permitem que os alunos visualizem o fluxo de execução de um programa e experimentem com algoritmos simples em português, facilitando a transição para linguagens como Python.
#
# ***Importância das Variáveis***
#
# Variáveis são fundamentais na programação, permitindo o armazenamento e manipulação de dados. Compreender como declarar e usar variáveis, bem como os diferentes tipos de dados, é essencial para qualquer programador iniciante.
#
# ***Estruturas de Repetição***
#
# Estruturas de repetição, como "enquanto" e "para", são cruciais para automatizar tarefas repetitivas. Elas permitem que um bloco de código seja executado várias vezes, economizando tempo e esforço na programação.
#
# ***Exemplo de utilização no mercado de trabalho:***
#
# - **Automação de Processos:** A lógica de programação e o uso de estruturas de repetição são frequentemente utilizados para automatizar processos em empresas, como a geração de relatórios ou o processamento de grandes volumes de dados.
#
# - **Desenvolvimento de Aplicações:** Compreender variáveis e lógica de programação é essencial no desenvolvimento de aplicações, onde é necessário manipular dados e criar funcionalidades que respondam a diferentes condições e entradas do usuário.

# %% [markdown]
# ### 3.9 **Reforce seu conhecimento**

# %% [markdown]
# ***Módulo 3***
#
# **Antes de revisar as respostas, tente respondê-las você mesmo, isso te ajudará a fortalecer sua compreensão. Esta é uma ótima maneira de aprender!**
#
# **Como o Portugol ajuda no aprendizado da lógica de programação?**
#
# O Portugol ajuda no aprendizado da lógica de programação ao permitir que os alunos pratiquem a escrita de algoritmos em português. Isso facilita a compreensão dos conceitos lógicos sem a barreira adicional de uma nova linguagem, preparando os alunos para transitar para linguagens como Python.
#
# **O que são variáveis e por que são importantes na programação?**
#
# Variáveis são espaços de armazenamento que mantêm dados que podem ser alterados durante a execução de um programa. Elas são importantes porque permitem que os programas manipulem dados de forma dinâmica, facilitando a automação de tarefas e a execução de operações complexas.
#
# **Como as estruturas de repetição são utilizadas na programação?**
#
# Estruturas de repetição, como "enquanto" e "para", são usadas para automatizar tarefas repetitivas em um programa. Elas permitem que um bloco de código seja executado várias vezes, economizando tempo e esforço ao evitar a necessidade de escrever código repetitivo manualmente.
#
# **Por que é importante praticar a lógica de programação com diferentes variáveis e cenários?**
#
# Praticar a lógica de programação com diferentes variáveis e cenários é importante porque ajuda a consolidar o aprendizado e a desenvolver uma compreensão mais profunda dos conceitos. A prática constante permite que os alunos experimentem e aprendam a aplicar a lógica de programação de forma eficaz em diferentes contextos.
#
# **Qual é a importância de uma base sólida em lógica de programação?**
#
# Uma base sólida em lógica de programação é crucial para evitar erros comuns e aplicar conhecimentos de forma eficaz. Compreender a lógica subjacente aos algoritmos permite que os programadores desenvolvam soluções eficientes e robustas, independentemente da linguagem de programação utilizada.

# %% [markdown]
# ### 3.10 **Quiz**

# %% [markdown]
# **Pergunta 1**
#
# **Considere o seguinte problema:**
#
# - Você está construindo um programa para simular um semáforo de trânsito. Qual estrutura de controle de fluxo você usaria para controlar o tempo de cada sinal?
#
# Condição "Se"
# correto
#
# A estrutura de controle de fluxo mais adequada para controlar o tempo de cada sinal de um semáforo de trânsito é a condição "Se", pois permite avaliar diferentes condições e tomar decisões com base nelas.
#
# **Pergunta 2**
#
# - Qual é o objetivo principal da estrutura de repetição em algoritmos?
#
# Repetir um conjunto de instruções várias vezes até que uma condição seja atendida.
# correto
#
# A estrutura de repetição é utilizada para executar um conjunto de instruções várias vezes, de acordo com uma condição estabelecida. Isso é útil para automatizar tarefas que precisam ser repetidas múltiplas vezes.
#
# **Pergunta 3**
#
# - Qual é o propósito da estrutura condicional em um algoritmo?
#
# Executar uma sequência de instruções apenas se uma condição for verdadeira.
# correto
#
# A estrutura condicional é utilizada para controlar o fluxo de execução do programa, permitindo que determinadas instruções sejam executadas apenas se uma condição específica for verdadeira.

# %% [markdown]
# ### 3.11 **Projeto 1**

# %% [markdown]
# **Que tal praticar?**
#
# *Passo a passo:*
#
# - Desenvolva no Portugal um algoritmo capaz de imprimir na tela “Hello World”
#
# - Desenvolva no Portugal um algoritmo que seja capaz de receber um valor de X pela função Leia e calcular o valor e imprimir na tela o valor de Y para a função de segundo grau: y = x**2 + x*2 + 16 (Lembre-se: ** indica exponencial).
#
# Dica: Não se esqueça de definir as variaveis.
#
# - Para finalizar, desenvolva um algoritmo que receba (usando a função leia) 2 números e retorne o resto da divisão desses dois números na tela.
#
# Tempo estimado para resolução: 30 minutos
#
# Como submeter sua entrega: Tire print do algoritmo rodando corretamente e envie para os tutores no campo de entrega abaixo.

# %% [markdown]
# ### 3.12 **Recapitule a jornada**

# %% [markdown]
# *Módulo 3*
#
# **Parabéns por ter finalizado este módulo! Confira a competência e as habilidades que você adquiriu:**
#
# **Competência:**
#
# Compreender e aplicar a lógica de programação para resolver problemas e desenvolver algoritmos eficientes utilizando ferramentas como Portugol e plataformas como Google Colab.
#
# **Habilidades:**
#
# - 1
# Definir variáveis e estruturas de repetição para automatizar tarefas repetitivas em algoritmos.
#
# - 2
# Descrever a lógica de programação utilizando fluxogramas e a ferramenta Portugol para facilitar o aprendizado.

# %% [markdown]
# ## 4. Git

# %% [markdown]
# ### 4.0 **Sobre o trajeto**

# %% [markdown]
# ***Módulo 4***
#
# **Olá, desejamos boas-vindas ao módulo Git do curso Profissão: Cientista de Dados.**
#
# Neste módulo, você será introduzido ao Git e GitHub, ferramentas essenciais para controle de versão e colaboração em projetos de tecnologia. Aprenderemos a importância dessas ferramentas e como elas podem resolver problemas comuns enfrentados por profissionais e estudantes:
#
# **Instalação e Configuração**
#
# Iniciaremos com a instalação do Git em diferentes sistemas operacionais e a criação de um perfil no GitHub. Este passo é fundamental para garantir que você esteja preparado para utilizar essas ferramentas no seu dia a dia profissional.
#
# **Comandos Básicos do Git**
#
# Você aprenderá os comandos essenciais do Git, como `git init`, `git clone`, `git add`, `git commit`, e `git push`. Esses comandos são fundamentais para o gerenciamento de versões e colaboração em projetos.
#
# **Criação e Gerenciamento de Repositórios**
#
# Exploraremos como criar e gerenciar repositórios no GitHub, destacando a importância de publicar projetos para portfólios pessoais e trabalho em equipe. Também discutiremos a importância de um README bem estruturado.
#
# Este módulo é um passo crucial na sua jornada para se tornar um cientista de dados competente. As habilidades adquiridas aqui serão fundamentais para colaborar eficazmente em projetos de tecnologia. Continue avançando e prepare-se para o próximo módulo!

# %% [markdown]
# ### 4.1 **Conheça o Git e o GitHub**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir a importância do Git no controle de versão de projetos;
# - Descrever as funcionalidades do Git para colaboração em equipe;
# - Aplicar o uso do GitHub para hospedar e compartilhar projetos.

# %% [markdown]
# ### 4.2 **Instale o Git e prefil no GitHub**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir a importância do Git no gerenciamento de versões de código;
# - Demonstrar o processo de instalação do Git em diferentes sistemas operacionais;
# - Esquematizar a criação de um perfil no GitHub para portfólio profissional.

# %% [markdown]
# ### 4.3 **Crie seu portifóliio**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir um perfil no GitHub para destacar habilidades e projetos;
# - Descrever personalizações de perfil usando códigos e elementos dinâmicos;
# - Aplicar técnicas para criar um repositório especial com README no GitHub.

# %% [markdown]
# **Links úteis para personalização do seu perfil**
#
# - Ícones
#
# https://dev.to/envoy_/150-badges-for-github-pnk
#
# https://devicon.dev/
#
# - Emojis
#
# https://emojipedia.org/
#
# - MarkDown
#
# https://docs.pipz.com/central-de-ajuda/learning-center/guia-basico-de-markdown#open

# %% [markdown]
# ### 4.4 **Repositório**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir a importância de repositórios no GitHub para projetos de TI;
# - Descrever comandos básicos do Git para gerenciar repositórios;
# - Aplicar práticas de versionamento e colaboração em projetos no GitHub.

# %% [markdown]
# ### 4.5 **Read Me**

# %% [markdown]
# **Estamos iniciando a nossa aula. Nesse momento, dê play para:**
#
# - Definir os elementos essenciais de um arquivo README em projetos;
# - Explicar a importância do README para colaboração e transparência;
# - Aplicar boas práticas na criação de READMEs para projetos pessoais.

# %% [markdown]
# ### 4.6 **Glossário**

# %% [markdown]
# *Módulo 4*
#
# **Lembre-se dos termos mais utilizados durante o módulo.**
#
# **Controle de versão**
#
# Um sistema que registra alterações em um arquivo ou conjunto de arquivos ao longo do tempo, permitindo que você retorne a versões específicas mais tarde. É essencial para o desenvolvimento colaborativo de software.
#
# **Git**
#
# Um sistema de controle de versão distribuído, amplamente utilizado para rastrear mudanças no código-fonte durante o desenvolvimento de software. Ele permite que múltiplos desenvolvedores trabalhem em paralelo.
#
# **GitHub**
#
# Uma plataforma de hospedagem de código-fonte com controle de versão usando o Git. Oferece funcionalidades de colaboração, como revisão de código, gerenciamento de projetos e integração contínua.
#
# **README**
#
# Um arquivo de texto que fornece informações sobre outros arquivos em um diretório ou arquivo de projeto de software. Geralmente inclui instruções de instalação, uso e contribuição.
#
# **Repositório**
#
# Um local centralizado onde os dados são armazenados e gerenciados. No contexto do Git e GitHub, refere-se a um diretório ou espaço de armazenamento onde seu projeto reside.

# %% [markdown]
# ### 4.7 **Boas práticas**

# %% [markdown]
# Módulo 4
#
# Nesta seção você encontrará informações importantes que te ajudarão a aplicar efetivamente o que aprendeu.
#
# Utilização de Controle de Versão
#
# É fundamental utilizar o Git para controle de versão em projetos de ciência de dados. Isso permite rastrear alterações no código e nos dados, facilitando a colaboração e a reversão de mudanças quando necessário.
#
# Criação de Repositórios no GitHub
#
# Criar repositórios no GitHub para armazenar e compartilhar projetos de ciência de dados é uma prática recomendada. Isso não só ajuda na organização, mas também serve como um portfólio profissional acessível a recrutadores e colegas.
#
# Documentação com README
#
# Incluir um arquivo README bem estruturado em cada repositório é crucial. Ele deve fornecer uma visão geral do projeto, instruções de instalação, detalhes de contribuição e informações de licença, garantindo clareza e eficácia na comunicação.
#
# Personalização do Perfil no GitHub
#
# Personalizar o perfil no GitHub com informações pessoais e profissionais, além de projetos relevantes, pode aumentar a visibilidade e atratividade para recrutadores. Um perfil bem configurado é essencial para se destacar em processos seletivos.
#
# Exemplo de utilização no mercado de trabalho:
#
# - **Colaboração em Projetos de Ciência de Dados:** Equipes de ciência de dados em empresas utilizam Git e GitHub para colaborar em projetos, permitindo que múltiplos membros trabalhem simultaneamente em diferentes partes do projeto sem conflitos.
#
# - **Portfólio Profissional:** Cientistas de dados usam GitHub para criar portfólios online, onde podem demonstrar suas habilidades e projetos para potenciais empregadores, aumentando suas chances em processos seletivos.
#
# **Exemplo de código básico para iniciar um repositório Git:**
#
# ![Captura de Tela 2024-12-20 às 22.29.31.png](data:image/png;base64,...)
#
# Vamos discutir o código passo-a-passo:
#
# - git init: Inicializa um novo repositório Git no diretório atual.
# - git add .: Adiciona todos os arquivos do diretório atual ao repositório.
# - git commit -m "Initial commit": Faz o commit das mudanças com a mensagem "Initial commit".
# - git remote add origin: Conecta o repositório local a um repositório remoto no GitHub.
# - git push -u origin master: Envia as mudanças para o repositório remoto na branch master.

# %% [markdown]
# ### 4.8 **De olho no erro**

# %% [markdown]
# ***Módulo 4***
#
# **Aprenda a identificar e corrigir os erros mais comuns e torne seu código mais eficiente e confiável.**
#
# **01 Esquecer de inicializar um repositório Git.**
#
# - **Descrição:** Iniciantes frequentemente esquecem de inicializar um repositório Git antes de começar a trabalhar em um projeto, o que impede o uso de comandos Git subsequentes.
# - **Tipo de Erro:** Erro de configuração.
#
# ![Captura de Tela 2024-12-20 às 22.33.00.png](data:image/png;base64,...)
#
# - **Passo 1:** Navegue até o diretório do projeto no terminal.
# - **Passo 2:** Execute o comando git init para inicializar o repositório.
# - **Passo 3:** Agora, adicione arquivos com git add.
#
# **02 Não configurar o nome de usuário e email no Git.**
#
# - **Descrição:** Antes de fazer commits, é necessário configurar o nome de usuário e email no Git. Esquecer de fazer isso pode resultar em commits sem identificação adequada.
# - **Tipo de Erro:** Erro de configuração.
#
# ![Captura de Tela 2024-12-20 às 22.35.48.png](data:image/png;base64,...)
#
# - **Passo 1:** Execute git config --global user.name "Seu Nome" para definir seu nome.
# - **Passo 2:** Execute git config --global user.email "seuemail@exemplo.com" para definir seu email.
# - **Passo 3:** Agora, você pode fazer commits com identificação adequada.
#
# **03 Confundir `git pull` com `git fetch`.**
#
# - **Descrição:** Iniciantes podem confundir os comandos `git pull` e `git fetch`, levando a conflitos de mesclagem inesperados.
# - **Tipo de Erro:** Erro lógico.
#
# ![Captura de Tela 2024-12-20 às 22.38.19.png](data:image/png;base64,...)
#
# - **Passo 1:** Use git fetch para buscar mudanças sem mesclar.
# - **Passo 2:** Revise as mudanças buscadas.
# - **Passo 3:** Use git merge para mesclar as mudanças quando estiver pronto.
#
# **04 Ignorar arquivos importantes no .gitignore.**
#
# - **Descrição:** Iniciantes podem acidentalmente adicionar arquivos importantes ao `.gitignore`, impedindo que sejam rastreados pelo Git.
#
# - **Tipo de Erro:** Erro de configuração.
#
# ![Captura de Tela 2024-12-20 às 22.41.13.png](data:image/png;base64,...)
#
# - **Passo 1:** Revise o arquivo .gitignore regularmente.
# - **Passo 2:** Remova entradas que não deveriam ser ignoradas.
# - **Passo 3:** Adicione apenas arquivos que não devem ser rastreados.
#
# **05 Não criar um README adequado para o projeto.**
#
# - **Descrição:** Um erro comum é não criar um arquivo README ou criar um que não forneça informações suficientes sobre o projeto.
# - **Tipo de Erro:** Erro de documentação.
#
# ![Captura de Tela 2024-12-20 às 22.50.43.png](data:image/png;base64,...)
#
# - **Passo 1:** Inclua uma descrição clara do projeto.
# - **Passo 2:** Adicione instruções de instalação e uso.
# - **Passo 3:** Forneça informações sobre contribuição e licença.
#
#
# Se você não encontrar o erro específico nesta lista, consulte a documentação oficial do Git e GitHub para obter mais informações, ou pergunte aos tutores do curso.

# %% [markdown]
# ### 4.9 **Reforce seu conhecimento**

# %% [markdown]
# *Módulo 4*
#
# **Antes de revisar as respostas, tente respondê-las você mesmo, isso te ajudará a fortalecer sua compreensão. Esta é uma ótima maneira de aprender!**
#
# **O que é o Git e por que é importante?**
#
# O Git é um sistema de controle de versão amplamente utilizado que permite o rastreamento de mudanças no código-fonte e facilita a colaboração entre membros de uma equipe. Ele é importante porque resolve problemas comuns, como a perda de versões anteriores de arquivos e a desorganização em ambientes colaborativos.
#
# **Como o GitHub complementa o Git?**
#
# O GitHub é uma plataforma online que complementa o Git ao permitir o armazenamento e compartilhamento de projetos. Ele também serve como um portfólio profissional, onde desenvolvedores podem exibir seus projetos e colaborar com outros.
#
# **Quais são os passos iniciais para começar a usar o Git e o GitHub?**
#
# Os passos iniciais incluem a instalação do Git em seu sistema operacional e a criação de um perfil no GitHub. Esses passos são fundamentais para começar a gerenciar projetos e colaborar com outros desenvolvedores.
#
# **Por que é importante personalizar o perfil no GitHub?**
#
# Personalizar o perfil no GitHub é importante porque torna sua apresentação mais atraente para recrutadores. Incluir informações pessoais e profissionais, além de personalizar o perfil com códigos, pode ajudar a destacar suas habilidades e projetos.
#
# **Quais são alguns dos comandos básicos do Git que devo conhecer?**
#
# Alguns dos comandos básicos do Git que você deve conhecer incluem `git init`, `git clone`, `git add`, `git commit`, e `git push`. Esses comandos são essenciais para iniciar e gerenciar repositórios, adicionar mudanças, e enviar atualizações para o GitHub.
#
# **Qual é a importância do arquivo README em um projeto?**
#
# O arquivo README é importante porque fornece uma visão geral do projeto, instruções de instalação, detalhes de contribuição, créditos e informações de licença. Um README bem estruturado é essencial para garantir a clareza e eficácia na comunicação do projeto.
#
# **Como posso criar e gerenciar repositórios no GitHub?**
#
# Você pode criar e gerenciar repositórios no GitHub através da interface da plataforma. Isso envolve a criação de um novo repositório, a clonagem para seu ambiente local, e o uso de comandos Git para gerenciar o conteúdo e colaborar com outros.
#
# **Por que publicar projetos no GitHub é importante para meu portfólio?**
#
# Publicar projetos no GitHub é importante para seu portfólio porque demonstra suas habilidades e experiência em desenvolvimento de software. Isso pode ser um diferencial em processos seletivos, mostrando aos recrutadores seu trabalho e capacidade de colaborar em projetos.
#
# **Como o Git e o GitHub ajudam na colaboração em equipe?**
#
# O Git e o GitHub ajudam na colaboração em equipe ao permitir que vários desenvolvedores trabalhem no mesmo projeto simultaneamente, rastreando mudanças e gerenciando versões de forma eficiente. Isso facilita a comunicação e coordenação entre membros da equipe.
#
# **Qual é a importância de ter um perfil bem configurado no GitHub?**
#
# Ter um perfil bem configurado no GitHub é importante porque pode ajudar a se destacar em processos seletivos. Um perfil atraente e bem organizado demonstra profissionalismo e pode atrair a atenção de recrutadores e potenciais empregadores.

# %% [markdown]
# ### 4.10 **Quiz**

# %% [markdown]
# Pergunta 1
#
# - **Qual o benefício de usar o Git?**
#
# Controla o histórico de alterações de um projeto
# correto
#
# A resposta a) não descreve adequadamente os benefícios do Git, pois menciona apenas a hospedagem de código. A resposta b) está incorreta, pois o Git não se concentra em facilitar a análise de conflitos de código. A resposta d) está relacionada à instalação e configuração, não aos benefícios.
#
# Pergunta 2
#
# - **O que é um repositório no contexto do Git?**
#
# Uma pasta que contém todos os arquivos e histórico de um projeto
# correto
# A resposta b) está incorreta porque um repositório não é um único arquivo, mas sim uma pasta que contém todos os arquivos e histórico de um projeto. A resposta c) menciona uma plataforma de hospedagem, não um repositório.
#
# Pergunta 3
#
# - **Como você registra as mudanças do stage em um repositório Git?**
#
# Com o comando "git commit"
# correto
# A resposta a) está incorreta, pois o comando "git clone" não registra mudanças, mas clona um repositório. A resposta c) menciona o comando "git merge," que não está relacionado ao registro de mudanças do stage. A resposta d) menciona o comando "git push," que envia as mudanças para um repositório remoto, mas não as registra.

# %% [markdown]
# ### 4.11 **Pratique**

# %% [markdown]
# Segue meu perfil no github.
#
# https://github.com/wesley-lacerda
#
# Abraços,
#
# Wesley

# %% [markdown]
# ### 4.12 **Recapitule a jornada**

# %% [markdown]
# Módulo 4
#
# **Parabéns por ter finalizado este módulo! Confira a competência e as habilidades que você adquiriu:**
#
# **Competência:**
#
# Utilizar o Git e GitHub para controle de versão e colaboração em projetos, garantindo organização e eficiência no desenvolvimento de software.
#
# **Habilidades:**
# - 1
# Instalar o Git em diferentes sistemas operacionais e criar um perfil no GitHub.
#
# - 2
# Personalizar o perfil no GitHub, incluindo informações pessoais e profissionais, e usar códigos para torná-lo atraente.
#
# - 3
# Executar comandos básicos do Git, como `git init`, `git clone`, `git add`, `git commit`, e `git push`.
#
# - 4
# Criar e gerenciar repositórios no GitHub, publicando projetos para portfólios pessoais e trabalho em equipe.

# %% [markdown]
# ### 4.13 **Queremos saber sua opinião**

# %% [markdown]
# Pergunta 1
# Como você avaliaria a qualidade do ensino?
# Excelente
# Pergunta 2
# Quão útil é o material do curso (vídeo-aulas, apresentações, leituras, referências, etc) para o seu aprendizado?
# Muito útil
# Pergunta 3
# Com quanta clareza o professor explica o conteúdo do curso?
# Muita clareza
# Pergunta 4
# Como você avaliaria a qualidade das tarefas?
# Excelente
# Pergunta 5
# Quão úteis foram as tarefas de casa para o entendimento dos conteúdos?
# Muito úteis
# Pergunta 6
# Como você avaliaria o retorno do tutor às suas perguntas?
# Excelente
# Pergunta 7
# Deixe aqui seu comentário, elogio, reclamação ou sugestão.
# Aproveito para agradecer o upgrade do curso Profissão Cientista de Dados, a versão 2 é excelente, a didática é muito boa e de fácil entendimento. Os professores são ótimos, o bem estruturado roteiro dos vídeos é superior ao anterior, o material tem ótima qualidade. Enfim, tudo é muito bom e eu não poderia deixar de agradecer.
#
# Pergunta 8
# Autorizo o uso da minha resposta discursiva dada nessa pesquisa por parte da EBAC para fins institucionais e publicação em site, redes sociais e eventos.
# SIM

# %% [markdown]
# # C) **Python para Análise de dados**

# %% [markdown]
# ## 5. Lógica de Programação com Python

# %% [markdown]
# ### 5.0 Sobre o trajeto

# %% [markdown]
# ***Módulo 5***
#
# **Olá, desejamos boas-vindas ao módulo Lógica de programação com Python do curso Profissão: Cientista de Dados.**
#
# O Módulo 5 do curso oferece uma introdução abrangente aos conceitos fundamentais da programação em Python, utilizando o Google Colab como principal ferramenta de desenvolvimento. O módulo é estruturado em várias aulas, cada uma focada em diferentes aspectos essenciais para iniciantes:
#
# **Introdução ao Python e Google Colab**
#
# O Google Colab é uma plataforma web que permite a execução de códigos Python em um ambiente virtual. VOcê aprenderá a acessar o Colab, criar e manipular notebooks, e executar seu primeiro código Python utilizando a função print.
#
# **Boas Práticas e Operadores**
#
# Você analisará a importância de documentar o código com comentários e aprenderá os operadores aritméticos, relacionais e lógicos. A prática contínua e a documentação são essenciais para a manutenção e clareza do código.
#
# **Estruturas Condicionais**
#
# Você aprenderá estruturas condicionais (if, else, elif) e operadores lógicos. Também verá a importância da indentação e dos testes de mesa para verificar o comportamento do código em diferentes cenários.
#
# Este módulo fornece uma base sólida em Python e Google Colab, cobrindo desde a introdução e boas práticas até estruturas de dados e interação com o usuário. Vamos juntos avançar no seu caminho para se tornar um analista de dados de sucesso!

# %% [markdown]
# ### 5.1 Conheça o Python

# %% [markdown]
# Estamos iniciando a nossa primeira aula. Nesse momento, dê play para:
#
# - conhecer a história de criação da linguagem Python;
# - compreender como começar a utilizar o Python;
# - conhecer os sites que você utilizará no curso.

# %% [markdown]
# ### 5.2 Descubra os operadores

# %% [markdown]
# ### 5.3 Conheça as variáveis

# %% [markdown]
# ### 5.4 Interaja com usuário

# %% [markdown]
# ### 5.5 Conheça as estruturas condicionais

# %% [markdown]
# ### 5.6 Utilize listas de valores

# %% [markdown]
# ### 5.7 Aplique estruturas de repetição

# %% [markdown]
# ### 5.8 De olho no código

# %% [markdown]
# ### 5.9 Glossário

# %% [markdown]
# ### 5.10 Boas práticas

# %% [markdown]
# ### 5.11 De olho no erro

# %% [markdown]
# ### 5.12 Reforce seu conhecimento

# %% [markdown]
# ### 5.13 Quiz

# %% [markdown]
# ### 5.14 Pratique

# %% [markdown]
# ### 5.15 Recapitule a jornada

# %% [markdown]
# ## 6. Python: Criação de Script e IDE

# %% [markdown]
# ### 6.0 Sobre o trajeto

# %% [markdown]
# ### 6.1 Introdução ao Python

# %% [markdown]
# ### 6.2 IDEs para Python

# %% [markdown]
# ### 6.3 Instalação e Uso da IDE

# %% [markdown]
# ### 6.4 Configurações e boas práticas com a IDE

# %% [markdown]
# ### 6.5 Glossário

# %% [markdown]
# ### 6.6 Boas práticas

# %% [markdown]
# ### 6.7 De olho no erro

# %% [markdown]
# ### 6.8 Reforce seu conhecimento

# %% [markdown]
# ### 6.9 Quiz

# %% [markdown]
# ### 6.10 Pratique

# %% [markdown]
# ### 6.11 Recapitule a jornada

# %% [markdown]
# ## 7. Python: Coleta de Dados

# %% [markdown]
# ### 7.0 Sobre o trajeto

# %% [markdown]
# ### 7.1 Introdução à Coleta de Dados

# %% [markdown]
# ### 7.2 Coletando dados da Web

# %% [markdown]
# ### 7.3 Coletando dados da Web através das tags

# %% [markdown]
# ### 7.4 Trabalhando com APIs

# %% [markdown]
# ### 7.5 Estrutura de dados

# %% [markdown]
# ### 7.6 Gerar dados ficticios

# %% [markdown]
# ### 7.7 Glossário

# %% [markdown]
# ### 7.8 Boas práticas

# %% [markdown]
# ### 7.9 De olho no erro

# %% [markdown]
# ### 7.10 Reforce seu conhecimento

# %% [markdown]
# ### 7.11 Quiz

# %% [markdown]
# ### 7.12 Lab 7

# %% [markdown]
# ### 7.13 Recapitule a jornada

# %% [markdown]
# ## 8. Python: Tratamento de Dados

# %% [markdown]
# ### 8.0 Sobre o trajeto

# %% [markdown]
# ### 8.1 Introdução a tratamento de dados

# %% [markdown]
# ### 8.2 Limpeza de Dados

# %% [markdown]
# ### 8.3 Tratar Outliers

# %% [markdown]
# ### 8.4 Tratar dados inconsistenciais

# %% [markdown]
# ### 8.5 Glossário

# %% [markdown]
# ### 8.6 Boas práticas

# %% [markdown]
# ### 8.7 De olho no erro

# %% [markdown]
# ### 8.8 Reforce seu conhecimento

# %% [markdown]
# ### 8.9 Quiz

# %% [markdown]
# ### 8.10 Lab 8

# %% [markdown]
# ### 8.11 Recapitule a jornada

# %% [markdown]
# ## 9. Python: Preparação de Dados

# %% [markdown]
# ### 9.0 Sobre o trajeto

# %% [markdown]
# ### 9.1 Introdução à Preparação de Dados

# %% [markdown]
# ### 9.2 Normalização e Padronização

# %% [markdown]
# ### 9.3 Codificação de Variáveis Categóricas

# %% [markdown]
# ### 9.4 Engenharia de features

# %% [markdown]
# ### 9.5 Glossário

# %% [markdown]
# ### 9.6 Boas práticas

# %% [markdown]
# ### 9.7 De olho no erro

# %% [markdown]
# ### 9.8 Reforce seu conhecimento

# %% [markdown]
# ### 9.9 Quiz

# %% [markdown]
# ### 9.10 Lab 9

# %% [markdown]
# ### 9.11 Recapitule a jornada

# %% [markdown]
# ## 10. Python: Visualização de Dados

# %% [markdown]
# ### 10.0 Sobre o trajeto

# %% [markdown]
# ### 10.1 Introdução à Visualização de Dados

# %% [markdown]
# ### 10.2 Uso de Matplotlib

# %% [markdown]
# ### 10.3 Uso de Seaborn

# %% [markdown]
# ### 10.4 Exemplos de Gráficos

# %% [markdown]
# ### 10.5 Glossário

# %% [markdown]
# ### 10.6 Boas práticas

# %% [markdown]
# ### 10.7 De olho no erro

# %% [markdown]
# ### 10.8 Reforce seu conhecimento

# %% [markdown]
# ### 10.9 Quiz

# %% [markdown]
# ### 10.10 Pratique

# %% [markdown]
# ### 10.11 Recapitule a jornada

# %% [markdown]
# # D) **Fundamentos da descoberta de dados**

# %% [markdown]
# ## 11. Analytics 1: Storytelling

# %% [markdown]
# ### 11.0 Sobre o trajeto

# %% [markdown]
# ### 11.1 Conheça o Storytelling

# %% [markdown]
# ### 11.2 Compreenda o Storyline

# %% [markdown]
# ### 11.3 Comunicação com Stakeholders

# %% [markdown]
# ### 11.4 Aplicação dos conceitos no dia a dia

# %% [markdown]
# ### 11.5 Glossário

# %% [markdown]
# ### 11.6 Boas práticas

# %% [markdown]
# ### 11.7 De olho no erro

# %% [markdown]
# ### 11.8 Reforce seu conhecimento

# %% [markdown]
# ### 11.9 Quiz

# %% [markdown]
# ### 11.10 Pratique

# %% [markdown]
# ### 11.11 Projeto de Parceria | Semantix

# %% [markdown]
# ### 11.12 Recapitule a jornada

# %% [markdown]
# ## 12. Analytics 2: Elementos visuais

# %% [markdown]
# ### 12.0 Sobre o trajeto

# %% [markdown]
# ### 12.1 Importância da clareza nos elementos

# %% [markdown]
# ### 12.2 Tipos de gráficos

# %% [markdown]
# ### 12.3 Instale o Anaconda

# %% [markdown]
# ### 12.4 Construindo gráficos em Python

# %% [markdown]
# ### 12.5 Gráficos interativos

# %% [markdown]
# ### 12.6 Glossário

# %% [markdown]
# ### 12.7 Boas práticas

# %% [markdown]
# ### 12.8 De olho no erro

# %% [markdown]
# ### 12.9 Reforce seu conhecimento

# %% [markdown]
# ### 12.10 Quiz

# %% [markdown]
# ### 12.11 Pratique

# %% [markdown]
# ### 12.12 Recapitule a jornada

# %% [markdown]
# ## 13. Estatística Básica

# %% [markdown]
# ### 13.0 Sobre o trajeto

# %% [markdown]
# ### 13.1 Introdução a estatística

# %% [markdown]
# ### 13.2 Conceitos primários

# %% [markdown]
# ### 13.3 Aplicando conceitos em Python

# %% [markdown]
# ### 13.4 Aplicando conceitos em R

# %% [markdown]
# ### 13.5 Distribuição normal

# %% [markdown]
# ### 13.6 Glossário

# %% [markdown]
# ### 13.7 Boas práticas

# %% [markdown]
# ### 13.8 De olho no erro

# %% [markdown]
# ### 13.9 Reforce seu conhecimento

# %% [markdown]
# ### 13.10 Quiz

# %% [markdown]
# ### 13.11 Projeto 3

# %% [markdown]
# ### 13.12 Recapitule a jornada

# %% [markdown]
# # E) **Pré-modelagem**

# %% [markdown]
# ## 14. Pré Processamento dos Dados - A primeira etapa Pré Modelagem

# %% [markdown]
# ### 14.0 Sobre o trajeto

# %% [markdown]
# ### 14.1 Importância da limpeza e tratamento de dados

# %% [markdown]
# ### 14.2 Verifique e trate tipos de dados

# %% [markdown]
# ### 14.3 Trate dados ausentes - Parte I

# %% [markdown]
# ### 14.4 Trate dados ausentes - Parte II

# %% [markdown]
# ### 14.5 Conheça outros tipos de tratamentos

# %% [markdown]
# ### 14.6 Glossário

# %% [markdown]
# ### 14.7 Boas práticas

# %% [markdown]
# ### 14.8 De olho no erro

# %% [markdown]
# ### 14.9 Reforce seu conhecimento

# %% [markdown]
# ### 14.10 Quiz

# %% [markdown]
# ### 14.11 Pratique

# %% [markdown]
# ### 14.12 Recapitule a jornada

# %% [markdown]
# ## 15. Pré-Processamento dos Dados - A segunda etapa pré-modelagem

# %% [markdown]
# ### 15.0 Sobre o trajeto

# %% [markdown]
# ### 15.1 Introdução à análise exploratória dos dados

# %% [markdown]
# ### 15.2 Análise Univariada

# %% [markdown]
# ### 15.3 Detectando Outliers

# %% [markdown]
# ### 15.4 Análise Bivariada

# %% [markdown]
# ### 15.5 Glossário

# %% [markdown]
# ### 15.6 Boas práticas

# %% [markdown]
# ### 15.7 De olho no erro

# %% [markdown]
# ### 15.8 Reforce seu conhecimento

# %% [markdown]
# ### 15.9 Quiz

# %% [markdown]
# ### 15.10 Pratique

# %% [markdown]
# ### 15.11 Recapitule a jornada

# %% [markdown]
# ## 16. Machine Learning 2: Tipos de aprendizados

# %% [markdown]
# ### 16.0 Sobre o trajeto

# %% [markdown]
# ### 16.1 Tipos de aprendizados

# %% [markdown]
# ### 16.2 Aprendizado supervisionado

# %% [markdown]
# ### 16.3 Aprendizado não supervisionado

# %% [markdown]
# ### 16.4 Aprendizado por reforço

# %% [markdown]
# ### 16.5 Glossário

# %% [markdown]
# ### 16.6 Boas práticas

# %% [markdown]
# ### 16.7 Reforce seu conhecimento

# %% [markdown]
# ### 16.8 Reforce seu conhecimento

# %% [markdown]
# ### 16.9 Quiz

# %% [markdown]
# ### 16.10 Pratique

# %% [markdown]
# ### 16.11 Recapitule a jornada

# %% [markdown]
# ## 17. Correlação, Balanceamento, Variáveis Categóricas - A Terceira etapa Pré Modelagem

# %% [markdown]
# ### 17.0 Sobre o trajeto

# %% [markdown]
# ### 17.1 Correlação entre as variáveis

# %% [markdown]
# ### 17.2 Associação, Causalidade e Correlação

# %% [markdown]
# ### 17.3 Analisando a Correlação com Python

# %% [markdown]
# ### 17.4 Atributos Categóricos

# %% [markdown]
# ### 17.5 Separação entre bases: treino e teste

# %% [markdown]
# ### 17.6 Balanceamento dos dados-Smote

# %% [markdown]
# ### 17.7 Glossário

# %% [markdown]
# ### 17.8 Boas práticas

# %% [markdown]
# ### 17.9 Reforce seu conhecimento

# %% [markdown]
# ### 17.10 Quiz

# %% [markdown]
# ### 17.11 Projeto 4

# %% [markdown]
# ### 17.12 Recapitule a jornada

# %% [markdown]
# # F) **Primeiros modelos**

# %% [markdown]
# ## 18. Regressão Linear

# %% [markdown]
# ### 18.0 Sobre o trajeto

# %% [markdown]
# ### 18.1 Conceitos fundamentais

# %% [markdown]
# ### 18.2 Regressão Linear na prática

# %% [markdown]
# ### 18.3 Regressão Linear Simples com Python

# %% [markdown]
# ### 18.4 Avaliando o modelo

# %% [markdown]
# ### 18.5 Regressão Linear Múltipla

# %% [markdown]
# ### 18.6 Regressão Linear com a biblioteca StatsModels

# %% [markdown]
# ### 18.7 Glossário

# %% [markdown]
# ### 18.8 Boas práticas

# %% [markdown]
# ### 18.10 Reforce seu conhecimento

# %% [markdown]
# ### 18.11 Quiz

# %% [markdown]
# ### 18.12 Pratique

# %% [markdown]
# ### 18.13 Projeto de Parceria | Semantix

# %% [markdown]
# ### 18.14 Recapitule a jornada

# %% [markdown]
# ## 19. Estatística Aplicada

# %% [markdown]
# ### 19.0 Sobre o trajeto

# %% [markdown]
# ### 19.1 Estatística inferial

# %% [markdown]
# ### 19.2 Probabilidade: Aprofundando Conceitos

# %% [markdown]
# ### 19.3 Função Densidade de Probabilidade

# %% [markdown]
# ### 19.4 Teste de significância

# %% [markdown]
# ### 19.5 Conhecendo os Testes de Hipótese

# %% [markdown]
# ### 19.6 P - Value

# %% [markdown]
# ### 19.7 P - Aplicando no Python

# %% [markdown]
# ### 19.8 Glossário

# %% [markdown]
# ### 19.9 Boas práticas

# %% [markdown]
# ### 19.10 De olho no erro

# %% [markdown]
# ### 19.11 Reforce seu conhecimento

# %% [markdown]
# ### 19.12 Quiz

# %% [markdown]
# ### 19.13 Pratique

# %% [markdown]
# ### 19.14 Recapitule a jornada
